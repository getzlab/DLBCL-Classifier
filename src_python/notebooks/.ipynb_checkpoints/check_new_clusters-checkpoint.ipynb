# %%
import pandas as pd
import sklearn.metrics as skm
from matplotlib import pyplot as plt

# %%
new_clustering = pd.read_csv('../../data_tables/clustering_labels/GSM699_cluster_Sep_23_2022.bestclus.remapped.txt',
                            sep='\t', index_col=0)

new_clustering
# Out:
#                     cluster  silhouetteValue  unmapped_cluster
# SampleName
# DLBCL11470                1         0.091243                 1
# DLBCL_LS3809              1         0.133936                 1
# DLBCL10969                1         0.150620                 1
# DLBCL11454                1         0.210921                 1
# DLBCL11520                1         0.050706                 1
# ...                     ...              ...               ...
# DLBCL_LS2596              5         0.091813                 2
# DLBCL11595                5         0.086577                 2
# DLBCL10992                5         0.057065                 2
# DLBCL_RICOVER_1219        5         0.132630                 2
# DLBCL10860                5         0.062499                 2
#
# [699 rows x 3 columns]

# %%
old_clustering = pd.read_csv('../../data_tables/clustering_labels/GSM699_cluster_Aug_17_2022.bestclus.remapped.txt',
                            sep='\t', index_col=0)
old_clustering = old_clustering.loc[new_clustering.index]
old_clustering

# %%
skm.confusion_matrix(old_clustering['cluster'], new_clustering['cluster'])
# Out:
# array([[136,   4,   0,   1,   0],
#        [  0, 163,   1,   3,   1],
#        [  2,   2, 115,   0,   0],
#        [  1,   1,   1,  92,   5],
#        [  1,   1,   0,   1, 168]])

# %%
new_clustering['old_cluster'] = old_clustering['cluster']
diffs = new_clustering.loc[new_clustering['cluster'] != new_clustering['old_cluster']]
diffs.shape
# Out:
# (18, 4)

# %%
diffs
# Out:
#                     cluster  silhouetteValue  unmapped_cluster  old_cluster
# SampleName
# DLBCL_LS3866              1         0.162222                 2            4
# DLBCL10878                1         0.187573                 2            5
# DFCIDL001_DT              1         0.087471                 2            3
# DLBC_FF_8046_TP_NB        1         0.093700                 2            3
# DLBCL_RICOVER_105         2         0.103743                 5            5
# DLBCL10894                2        -0.004315                 5            1
# DLBCL10549                2         0.170503                 5            3
# DLBCL11455                3        -0.012815                 1            4
# DLBCL_RICOVER_1046        3        -0.066046                 1            2
# DLBCL10524                4         0.111992                 4            2
# DLBCL_RICOVER_1204        4         0.142584                 4            5
# DLBCL_LS1668              4         0.122815                 4            2
# DLBCL11659                4        -0.010075                 4            1
# DLBCL10985                4         0.128241                 4            2
# DLBCL11538                5         0.138481                 3            4
# DLBCL11504                5         0.170688                 3            4
# DLBCL10948                5         0.014568                 3            2
# DLBCL_RICOVER_597         5         0.013466                 3            4

# %%
confidences = pd.read_csv('../../data_tables/confidence_tables/baseline_probabilities.connectivity_based.sensitivity_power2.Sep_23_2022.tsv',
                         sep='\t', index_col=0)
diff_c = confidences.loc[diffs.index]
diff_c
# Out:
#                           C1        C2        C3        C4        C5  cluster  \
# SampleName
# DLBCL_LS3866        0.507197  0.000391  0.000954  0.488731  0.002727        1
# DLBCL10878          0.507153  0.001672  0.000258  0.001655  0.489261        1
# DFCIDL001_DT        0.978677  0.000795  0.005841  0.014596  0.000091        1
# DLBC_FF_8046_TP_NB  0.507221  0.002809  0.000589  0.002546  0.486836        1
# DLBCL_RICOVER_105   0.056322  0.455224  0.054787  0.057303  0.376364        2
# DLBCL10894          0.474393  0.515370  0.002700  0.005965  0.001572        2
# DLBCL10549          0.000113  0.777197  0.218627  0.002758  0.001305        2
# DLBCL11455          0.011917  0.000523  0.543346  0.443870  0.000344        3
# DLBCL_RICOVER_1046  0.000203  0.309759  0.683105  0.005672  0.001260        3
# DLBCL10524          0.011142  0.475846  0.005474  0.501542  0.005996        4
# DLBCL_RICOVER_1204  0.004548  0.002634  0.001029  0.505987  0.485801        4
# DLBCL_LS1668        0.004564  0.375409  0.089056  0.529728  0.001242        4
# DLBCL11659          0.125813  0.000739  0.076857  0.794851  0.001740        4
# DLBCL10985          0.014841  0.478416  0.005262  0.500048  0.001433        4
# DLBCL11538          0.003908  0.000575  0.210265  0.232474  0.552779        5
# DLBCL11504          0.173755  0.000432  0.000589  0.284391  0.540833        5
# DLBCL10948          0.000981  0.361435  0.000410  0.008202  0.628973        5
# DLBCL_RICOVER_597   0.006521  0.001989  0.001767  0.227116  0.762607        5
#
#                     confidence
# SampleName
# DLBCL_LS3866          0.507197
# DLBCL10878            0.507153
# DFCIDL001_DT          0.978677
# DLBC_FF_8046_TP_NB    0.507221
# DLBCL_RICOVER_105     0.455224
# DLBCL10894            0.515370
# DLBCL10549            0.777197
# DLBCL11455            0.543346
# DLBCL_RICOVER_1046    0.683105
# DLBCL10524            0.501542
# DLBCL_RICOVER_1204    0.505987
# DLBCL_LS1668          0.529728
# DLBCL11659            0.794851
# DLBCL10985            0.500048
# DLBCL11538            0.552779
# DLBCL11504            0.540833
# DLBCL10948            0.628973
# DLBCL_RICOVER_597     0.762607

# %%
plt.figure(figsize=(8,6))
plt.hist(diff_c['confidence'], bins=30)
plt.xlabel('Confidence')
plt.show()

# %%
import pandas as pd

# %%
sample_sets = pd.read_csv('/Users/twood/Downloads/sample_set/sample_set_membership.tsv', sep='\t', index_col=0)
sample_sets
# Out:
#                                                         sample
# membership:sample_set_id
# shipp_dlbclass_tumor_samples               DLBCL_P01_p_to_r-Dx
# shipp_dlbclass_tumor_samples               DLBCL_P10_p_to_r-Dx
# shipp_dlbclass_tumor_samples  DLBCL-RICOVER_290-Tumor-SM-4NFSO
# shipp_dlbclass_tumor_samples  DLBCL-RICOVER_451-Tumor-SM-4NFTI
# shipp_dlbclass_tumor_samples  DLBCL-RICOVER_473-Tumor-SM-4NFTN
# ...                                                        ...
# shipp_dlbclass_tumor_samples   DLBCL-c_D_pair20-Tumor-SM-671HV
# shipp_dlbclass_tumor_samples   DLBCL-c_D_pair22-Tumor-SM-671I5
# shipp_dlbclass_tumor_samples   DLBCL-c_D_pair23-Tumor-SM-671I9
# shipp_dlbclass_tumor_samples    DLBCL-c_D_pair5-Tumor-SM-671H9
# shipp_dlbclass_tumor_samples    DLBCL-c_D_pair9-Tumor-SM-671HJ
#
# [277 rows x 1 columns]

# %%
normal_samples = pd.read_csv('/Users/twood/Downloads/sample.tsv', sep='\t', index_col=0)
normal_samples = normal_samples.loc[~normal_samples.index.str.contains('Tumor')]
normal_samples = normal_samples.loc[~normal_samples.index.str.contains('NULL')]
normal_samples = normal_samples.loc[~normal_samples['dlbclass_name'].isna()]
normal_samples = normal_samples.loc[~normal_samples.index.isin(['DLBCL_P01_p_to_r-Dx',
                                                                'DLBCL_P03_p_to_r-Dx',
                                                                'DLBCL_P04_p_to_r-Dx',
                                                                'DLBCL_P10_p_to_r-Dx']))
normal_samples
# Out:
#                                            dlbclass_name  \
# entity:sample_id
# DFCI_DLBCL_Goe05-Normal           DLBCL_DFCI_DLBCL_GOE05
# DFCI_DLBCL_Goe07-Normal           DLBCL_DFCI_DLBCL_GOE07
# DFCI_DLBCL_Goe16-Normal           DLBCL_DFCI_DLBCL_GOE16
# DLBCL-LS2325-Normal                         DLBCL_LS2325
# DLBCL-LS4054-Normal                         DLBCL_LS4054
# ...                                                  ...
# DLBCL-RICOVER_99-Normal-SM-4MEWY        DLBCL_RICOVER_99
# DLBCL_P01_p_to_r-Dx                         DFCIDL001_DT
# DLBCL_P03_p_to_r-Dx                         DFCIDL003_DT
# DLBCL_P04_p_to_r-Dx                         DFCIDL004_DT
# DLBCL_P10_p_to_r-Dx                         DFCIDL010_DT
#
#                                                              clean_bam_file_capture
# entity:sample_id
# DFCI_DLBCL_Goe05-Normal           gs://fc-89e1fbf6-1d73-400b-b134-af6c183e4ab7/L...
# DFCI_DLBCL_Goe07-Normal           gs://fc-89e1fbf6-1d73-400b-b134-af6c183e4ab7/L...
# DFCI_DLBCL_Goe16-Normal           gs://fc-89e1fbf6-1d73-400b-b134-af6c183e4ab7/L...
# DLBCL-LS2325-Normal               gs://fc-89e1fbf6-1d73-400b-b134-af6c183e4ab7/L...
# DLBCL-LS4054-Normal               gs://fc-89e1fbf6-1d73-400b-b134-af6c183e4ab7/L...
# ...                                                                             ...
# DLBCL-RICOVER_99-Normal-SM-4MEWY  gs://fc-e48a9f2f-4be8-4d2e-8ceb-1636ad7663ad/G...
# DLBCL_P01_p_to_r-Dx               gs://fc-89e1fbf6-1d73-400b-b134-af6c183e4ab7/L...
# DLBCL_P03_p_to_r-Dx               gs://fc-89e1fbf6-1d73-400b-b134-af6c183e4ab7/L...
# DLBCL_P04_p_to_r-Dx               gs://fc-89e1fbf6-1d73-400b-b134-af6c183e4ab7/L...
# DLBCL_P10_p_to_r-Dx               gs://fc-89e1fbf6-1d73-400b-b134-af6c183e4ab7/L...
#
# [128 rows x 2 columns]

# %%
for n in normal_samples.index:
    if 'Tum' in n or 'tum' in n or ('norm' not in n and 'Norm' not in n):
        print(n)
# Out:
# DLBCL_P01_p_to_r-Dx
# DLBCL_P03_p_to_r-Dx
# DLBCL_P04_p_to_r-Dx
# DLBCL_P10_p_to_r-Dx

# %%
sample_sets
# Out:
#                                                         sample
# membership:sample_set_id
# shipp_dlbclass_tumor_samples               DLBCL_P01_p_to_r-Dx
# shipp_dlbclass_tumor_samples               DLBCL_P10_p_to_r-Dx
# shipp_dlbclass_tumor_samples  DLBCL-RICOVER_290-Tumor-SM-4NFSO
# shipp_dlbclass_tumor_samples  DLBCL-RICOVER_451-Tumor-SM-4NFTI
# shipp_dlbclass_tumor_samples  DLBCL-RICOVER_473-Tumor-SM-4NFTN
# ...                                                        ...
# shipp_dlbclass_tumor_samples   DLBCL-c_D_pair20-Tumor-SM-671HV
# shipp_dlbclass_tumor_samples   DLBCL-c_D_pair22-Tumor-SM-671I5
# shipp_dlbclass_tumor_samples   DLBCL-c_D_pair23-Tumor-SM-671I9
# shipp_dlbclass_tumor_samples    DLBCL-c_D_pair5-Tumor-SM-671H9
# shipp_dlbclass_tumor_samples    DLBCL-c_D_pair9-Tumor-SM-671HJ
#
# [277 rows x 1 columns]

# %%
normal_sample_set
# Out:
#                                                           sample
# membership:sample_set_id
# shipp_dlbclass_normal_samples            DFCI_DLBCL_Goe01-Normal
# shipp_dlbclass_normal_samples            DFCI_DLBCL_Goe05-Normal
# shipp_dlbclass_normal_samples            DFCI_DLBCL_Goe07-Normal
# shipp_dlbclass_normal_samples            DFCI_DLBCL_Goe08-Normal
# shipp_dlbclass_normal_samples            DFCI_DLBCL_Goe13-Normal
# ...                                                          ...
# shipp_dlbclass_normal_samples  DLBCL-RICOVER_977-Normal-SM-4MEZD
# shipp_dlbclass_normal_samples  DLBCL-RICOVER_983-Normal-SM-4JPFW
# shipp_dlbclass_normal_samples   DLBCL-RICOVER_99-Normal-SM-4MEWY
# shipp_dlbclass_normal_samples  DLBCL-RICOVER_996-Normal-SM-4MEZF
# shipp_dlbclass_normal_samples                       LS155_Normal
#
# [188 rows x 1 columns]

# %%
normal_sample_set = pd.DataFrame(columns=['membership:sample_set_id', 'sample'])
normal_sample_set['sample'] = normal_samples.index
normal_sample_set['membership:sample_set_id'] = 'shipp_dlbclass_normal_samples'
normal_sample_set = normal_sample_set.set_index('membership:sample_set_id')

# %%
sample_sets_all = pd.concat([normal_sample_set, sample_sets])
sample_sets_all.to_csv('terra_metadata_allSampleSets.tsv', sep='\t')
sample_sets_all
# Out:
#                                                         sample
# membership:sample_set_id
# shipp_dlbclass_normal_samples          DFCI_DLBCL_Goe01-Normal
# shipp_dlbclass_normal_samples          DFCI_DLBCL_Goe05-Normal
# shipp_dlbclass_normal_samples          DFCI_DLBCL_Goe07-Normal
# shipp_dlbclass_normal_samples          DFCI_DLBCL_Goe08-Normal
# shipp_dlbclass_normal_samples          DFCI_DLBCL_Goe13-Normal
# ...                                                        ...
# shipp_dlbclass_tumor_samples   DLBCL-c_D_pair20-Tumor-SM-671HV
# shipp_dlbclass_tumor_samples   DLBCL-c_D_pair22-Tumor-SM-671I5
# shipp_dlbclass_tumor_samples   DLBCL-c_D_pair23-Tumor-SM-671I9
# shipp_dlbclass_tumor_samples    DLBCL-c_D_pair5-Tumor-SM-671H9
# shipp_dlbclass_tumor_samples    DLBCL-c_D_pair9-Tumor-SM-671HJ
#
# [465 rows x 1 columns]

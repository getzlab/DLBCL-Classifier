# %%
import pandas as pd

# %%
natmed_gsm = pd.read_csv("../../data_tables/gsm/DLBCL_significant_event_matrix_NatMed.txt", sep='\t', index_col=0)
natmed_gsm.index = natmed_gsm.index.str.replace(':', '.').str.replace('-', '.').str.upper()
natmed_gsm.index = ['X' + x if '.AMP' in x or '.DEL' in x else x for x in natmed_gsm.index]
natmed_gsm
# Out:
#                    DFCIDL001_DT  DFCIDL002_DT  DFCIDL003_DT  DFCIDL004_DT  \
# ACTB                          0             0             0             0
# B2M                           2             0             0             0
# BCL10                         0             0             0             0
# BCL11A                        0             0             0             0
# BCL2                          0             0             0             0
# ...                         ...           ...           ...           ...
# SV.MYC                        0             0             0             0
# SV.CD274/PDCD1LG2             3             0             0             3
# SV.TBL1XR1                    0             0             0             0
# SV.CIITA                      3             0             0             3
# SV.ETV6                       0             0             0             0
#
#                    DFCIDL007_DT  DFCIDL008_DT  DFCIDL009_DT  DFCIDL010_DT  \
# ACTB                          0             0             0             0
# B2M                           0             0             0             2
# BCL10                         0             0             0             0
# BCL11A                        0             0             0             0
# BCL2                          0             0             1             0
# ...                         ...           ...           ...           ...
# SV.MYC                        0             0             3             0
# SV.CD274/PDCD1LG2             0             0             0             0
# SV.TBL1XR1                    0             0             0             0
# SV.CIITA                      0             0             0             0
# SV.ETV6                       0             0             0             0
#
#                    DLBCL_BWH_DLBCL64  DLBCL_c_D_1103_nullpair  ...  \
# ACTB                               0                        0  ...
# B2M                                0                        0  ...
# BCL10                              0                        0  ...
# BCL11A                             0                        0  ...
# BCL2                               0                        0  ...
# ...                              ...                      ...  ...
# SV.MYC                             0                        0  ...
# SV.CD274/PDCD1LG2                  0                        0  ...
# SV.TBL1XR1                         0                        0  ...
# SV.CIITA                           0                        0  ...
# SV.ETV6                            0                        0  ...
#
#                    DLBCL_RICOVER_866  DLBCL_RICOVER_910  DLBCL_RICOVER_945  \
# ACTB                               0                  0                  0
# B2M                                0                  0                  2
# BCL10                              0                  0                  0
# BCL11A                             0                  0                  0
# BCL2                               2                  0                  0
# ...                              ...                ...                ...
# SV.MYC                             0                  0                  0
# SV.CD274/PDCD1LG2                  0                  0                  0
# SV.TBL1XR1                         0                  0                  0
# SV.CIITA                           0                  0                  0
# SV.ETV6                            0                  0                  0
#
#                    DLBCL_RICOVER_948  DLBCL_RICOVER_950  DLBCL_RICOVER_956  \
# ACTB                               0                  2                  0
# B2M                                0                  0                  0
# BCL10                              0                  0                  0
# BCL11A                             0                  0                  0
# BCL2                               0                  0                  0
# ...                              ...                ...                ...
# SV.MYC                             0                  0                  0
# SV.CD274/PDCD1LG2                  0                  0                  0
# SV.TBL1XR1                         0                  0                  0
# SV.CIITA                           0                  0                  0
# SV.ETV6                            0                  0                  0
#
#                    DLBCL_RICOVER_977  DLBCL_RICOVER_978  DLBCL_RICOVER_985  \
# ACTB                               0                  2                  0
# B2M                                0                  0                  0
# BCL10                              2                  2                  0
# BCL11A                             0                  2                  0
# BCL2                               0                  0                  0
# ...                              ...                ...                ...
# SV.MYC                             0                  0                  0
# SV.CD274/PDCD1LG2                  0                  0                  0
# SV.TBL1XR1                         0                  0                  0
# SV.CIITA                           0                  0                  0
# SV.ETV6                            0                  0                  0
#
#                    DLBCL_RICOVER_99
# ACTB                              0
# B2M                               0
# BCL10                             0
# BCL11A                            0
# BCL2                              0
# ...                             ...
# SV.MYC                            0
# SV.CD274/PDCD1LG2                 0
# SV.TBL1XR1                        0
# SV.CIITA                          0
# SV.ETV6                           0
#
# [158 rows x 304 columns]

# %%
clus_gsm = pd.read_csv("../../data_tables/gsm/DLBCL.699.fullGSM.Sep_23_2022.CLUSTERING.tsv", sep='\t', index_col=0)
clus_gsm
# Out:
#                DLBCL11470  DLBCL10900  DLBC_FF_A7CQ_TP_NB  DLBCL10462  \
# gene
# STAT3                 0.0         0.0                 0.0         0.0
# BCL11A                0.0         0.0                 0.0         0.0
# PIM1                  2.0         2.0                 2.0         2.0
# DTX1                  2.0         1.0                 0.0         0.0
# NLRP8                 0.0         0.0                 0.0         0.0
# ...                   ...         ...                 ...         ...
# X19P13.2.DEL          0.0         0.0                 0.0         0.0
# SV.BCL2               0.0         0.0                 0.0         0.0
# SV.BCL6               3.0         0.0                 0.0         3.0
# SV.MYC                0.0         0.0                 0.0         0.0
# X19Q13.32.DEL         0.0         0.0                 0.0         0.0
#
#                DLBCL_RICOVER_1081  DLBCL_LS1098  DLBCL_RICOVER_299  \
# gene
# STAT3                         2.0           0.0                0.0
# BCL11A                        0.0           0.0                0.0
# PIM1                          0.0           0.0                2.0
# DTX1                          0.0           0.0                0.0
# NLRP8                         0.0           0.0                0.0
# ...                           ...           ...                ...
# X19P13.2.DEL                  0.0           0.0                1.0
# SV.BCL2                       0.0           3.0                3.0
# SV.BCL6                       0.0           0.0                0.0
# SV.MYC                        0.0           0.0                0.0
# X19Q13.32.DEL                 0.0           0.0                1.0
#
#                DLBCL11558  DLBCL_C_D_1105_NULLPAIR  DLBCL11447  ...  \
# gene                                                            ...
# STAT3                 0.0                      0.0         0.0  ...
# BCL11A                0.0                      0.0         0.0  ...
# PIM1                  0.0                      0.0         2.0  ...
# DTX1                  0.0                      2.0         0.0  ...
# NLRP8                 0.0                      0.0         0.0  ...
# ...                   ...                      ...         ...  ...
# X19P13.2.DEL          0.0                      0.0         0.0  ...
# SV.BCL2               3.0                      0.0         0.0  ...
# SV.BCL6               0.0                      0.0         0.0  ...
# SV.MYC                0.0                      0.0         0.0  ...
# X19Q13.32.DEL         0.0                      0.0         0.0  ...
#
#                DLBCL11455  DLBCL_RICOVER_685  DLBCL_LS146  DLBCL_RICOVER_111  \
# gene
# STAT3                 2.0                0.0          0.0                0.0
# BCL11A                0.0                0.0          0.0                1.0
# PIM1                  0.0                2.0          0.0                0.0
# DTX1                  1.0                0.0          0.0                0.0
# NLRP8                 0.0                0.0          0.0                0.0
# ...                   ...                ...          ...                ...
# X19P13.2.DEL          0.0                1.0          1.0                0.0
# SV.BCL2               0.0                0.0          0.0                0.0
# SV.BCL6               0.0                0.0          0.0                0.0
# SV.MYC                0.0                0.0          0.0                0.0
# X19Q13.32.DEL         0.0                0.0          0.0                0.0
#
#                DLBCL_RICOVER_173  DLBCL11515  DLBCL10491  DLBCL_RICOVER_1046  \
# gene
# STAT3                        0.0         0.0         0.0                 0.0
# BCL11A                       0.0         0.0         0.0                 0.0
# PIM1                         0.0         0.0         0.0                 0.0
# DTX1                         0.0         0.0         0.0                 0.0
# NLRP8                        0.0         0.0         0.0                 0.0
# ...                          ...         ...         ...                 ...
# X19P13.2.DEL                 0.0         0.0         0.0                 0.0
# SV.BCL2                      0.0         0.0         0.0                 3.0
# SV.BCL6                      0.0         0.0         0.0                 0.0
# SV.MYC                       0.0         3.0         3.0                 0.0
# X19Q13.32.DEL                0.0         0.0         0.0                 0.0
#
#                DLBCL10547  DLBCL10998
# gene
# STAT3                 0.0         0.0
# BCL11A                0.0         0.0
# PIM1                  2.0         0.0
# DTX1                  0.0         0.0
# NLRP8                 0.0         0.0
# ...                   ...         ...
# X19P13.2.DEL          0.0         0.0
# SV.BCL2               0.0         0.0
# SV.BCL6               0.0         0.0
# SV.MYC                0.0         0.0
# X19Q13.32.DEL         0.0         0.0
#
# [150 rows x 699 columns]

# %%
[x for x in natmed_gsm.index if x not in clus_gsm.index]
# Out:
# ['HIST1H2BK',
#  'HIST2H2BE',
#  'PDE4DIP',
#  'X18Q21.33(BCL2).AMP',
#  'SV.TP63',
#  'SV.CD274/PDCD1LG2',
#  'SV.TBL1XR1',
#  'SV.CIITA',
#  'SV.ETV6']

# %%
amps = [x for x in clus_gsm.index if '.AMP' in x]
dels = [x for x in clus_gsm.index if '.DEL' in x]
svs = [x for x in clus_gsm.index if 'SV.' in x]
muts = [x for x in clus_gsm.index if x not in amps and x not in dels and x not in svs]

# %%
len(amps), len(dels), len(svs), len(muts)
# Out:
# (32, 33, 3, 82)

# %%
sum([len(amps), len(dels), len(svs), len(muts)])
# Out:
# 150

# %%
full_gsm = pd.read_csv('../../data_tables/gsm/DLBCL.699.fullGSM.Sep_23_2022.tsv', sep='\t', index_col=0)
full_gsm = full_gsm.loc[~full_gsm.index.str.contains('.CCF')]
full_gsm
# Out:
#               DLBCL11470 DLBCL10900 DLBC_FF_A7CQ_TP_NB DLBCL10462  \
# 0
# STAT3                0.0        0.0                0.0        0.0
# STK33                0.0        0.0                0.0        0.0
# OSBPL10              0.0        2.0                1.0        0.0
# BCL11A               0.0        0.0                0.0        0.0
# PIM1                 2.0        2.0                2.0        2.0
# ...                  ...        ...                ...        ...
# X19P13.2.DEL         0.0        0.0                0.0        0.0
# SV.BCL2                0          0                  0          0
# SV.BCL6                3          0                  0          3
# SV.MYC                 0          0                  0          0
# X19Q13.32.DEL        0.0        0.0                0.0        0.0
#
#               DLBCL_RICOVER_1081 DLBCL_LS1098 DLBCL_RICOVER_299 DLBCL11558  \
# 0
# STAT3                        2.0          0.0               0.0        0.0
# STK33                        0.0          0.0               0.0        0.0
# OSBPL10                      0.0          0.0               0.0        0.0
# BCL11A                       0.0          0.0               0.0        0.0
# PIM1                         0.0          0.0               2.0        0.0
# ...                          ...          ...               ...        ...
# X19P13.2.DEL                 0.0          0.0               1.0        0.0
# SV.BCL2                        0            3                 3          3
# SV.BCL6                        0            0                 0          0
# SV.MYC                         0            0                 0          0
# X19Q13.32.DEL                0.0          0.0               1.0        0.0
#
#               DLBCL_C_D_1105_NULLPAIR DLBCL11447  ... DLBCL11455  \
# 0                                                 ...
# STAT3                             0.0        0.0  ...        2.0
# STK33                             0.0        0.0  ...        0.0
# OSBPL10                           0.0        1.0  ...        2.0
# BCL11A                            0.0        0.0  ...        0.0
# PIM1                              0.0        2.0  ...        0.0
# ...                               ...        ...  ...        ...
# X19P13.2.DEL                      0.0        0.0  ...        0.0
# SV.BCL2                             0          0  ...          0
# SV.BCL6                             0          0  ...          0
# SV.MYC                              0          0  ...          0
# X19Q13.32.DEL                     0.0        0.0  ...        0.0
#
#               DLBCL_RICOVER_685 DLBCL_LS146 DLBCL_RICOVER_111  \
# 0
# STAT3                       0.0         0.0               0.0
# STK33                       0.0         0.0               0.0
# OSBPL10                     0.0         0.0               0.0
# BCL11A                      0.0         0.0               1.0
# PIM1                        2.0         0.0               0.0
# ...                         ...         ...               ...
# X19P13.2.DEL                1.0         1.0               0.0
# SV.BCL2                       0           0                 0
# SV.BCL6                       0           0                 0
# SV.MYC                        0           0                 0
# X19Q13.32.DEL               0.0         0.0               0.0
#
#               DLBCL_RICOVER_173 DLBCL11515 DLBCL10491 DLBCL_RICOVER_1046  \
# 0
# STAT3                       0.0        0.0        0.0                0.0
# STK33                       0.0        0.0        0.0                0.0
# OSBPL10                     0.0        2.0        0.0                0.0
# BCL11A                      0.0        0.0        0.0                0.0
# PIM1                        0.0        0.0        0.0                0.0
# ...                         ...        ...        ...                ...
# X19P13.2.DEL                  0        0.0        0.0                0.0
# SV.BCL2                       0          0          0                3.0
# SV.BCL6                       0          0          0                0.0
# SV.MYC                        0          3          3                0.0
# X19Q13.32.DEL                 0        0.0        0.0                0.0
#
#               DLBCL10547 DLBCL10998
# 0
# STAT3                0.0        0.0
# STK33                0.0        0.0
# OSBPL10              0.0        0.0
# BCL11A               0.0        0.0
# PIM1                 2.0        0.0
# ...                  ...        ...
# X19P13.2.DEL         0.0        0.0
# SV.BCL2                0          0
# SV.BCL6                0          0
# SV.MYC                 0          0
# X19Q13.32.DEL        0.0        0.0
#
# [281 rows x 699 columns]

# %%
amps = [x for x in full_gsm.index if '.AMP' in x]
dels = [x for x in full_gsm.index if '.DEL' in x]
svs = [x for x in full_gsm.index if 'SV' in x]
muts = [x for x in full_gsm.index if x not in amps and x not in dels and x not in svs]
muts = [x for x in muts if x != 'COO' and x != 'PLOIDY' and x != 'PURITY']
len(amps), len(dels), len(svs), len(muts)
# Out:
# (34, 33, 3, 208)

# %%
208 + 34 + 33 + 3
# Out:
# 278

# %%
qvals = pd.read_csv('../../data_tables/qval_dfs/fisher_exact_5x2.Sep_23_2022.combined.tsv', sep='\t')
qvals

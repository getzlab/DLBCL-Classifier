# %%
import os
if "R_HOME" not in os.environ:
    os.environ['R_HOME'] = '/Library/Frameworks/R.framework/Resources/'
import numpy as np
import rpy2.robjects.numpy2ri
import rpy2.robjects as R
from rpy2.robjects.packages import importr
rpy2.robjects.numpy2ri.activate()
import pandas as pd
import statsmodels.stats.multitest as sm

R.r('set.seed')(1)

R_STATS = importr('stats')

def fisher_exact_2x2(matrix, alt):
    return R_STATS.fisher_test(matrix, alternative=alt)

# %%
gsm = pd.read_csv('../../data_tables/gsm/DLBCL.699.163drivers.Sep_23_2022.tsv', sep='\t', index_col=1)
gsm = gsm.drop('gene', axis=1)
gsm
# Out:
#                  DLBCL11470  DLBCL10900  DLBC_FF_A7CQ_TP_NB  DLBCL10462  \
# classifier_name
# SV.BCL6                   3           0                   0           3
# DTX1                      2           1                   0           0
# CD70                      2           0                   0           0
# TNFAIP3                   2           0                   0           2
# NOTCH2                    0           0                   0           2
# ...                     ...         ...                 ...         ...
# X1Q32.1.AMP               0           0                   0           0
# BCL11A                    0           0                   0           0
# IRF4                      0           2                   2           0
# LYN                       0           0                   0           0
# ETS1                      2           0                   0           0
#
#                  DLBCL_RICOVER_1081  DLBCL_LS1098  DLBCL_RICOVER_299  \
# classifier_name
# SV.BCL6                           0             0                  0
# DTX1                              0             0                  0
# CD70                              2             0                  0
# TNFAIP3                           0             0                  0
# NOTCH2                            0             0                  0
# ...                             ...           ...                ...
# X1Q32.1.AMP                       1             0                  0
# BCL11A                            0             0                  0
# IRF4                              0             0                  0
# LYN                               2             0                  0
# ETS1                              0             0                  0
#
#                  DLBCL11558  DLBCL_C_D_1105_NULLPAIR  DLBCL11447  ...  \
# classifier_name                                                   ...
# SV.BCL6                   0                        0           0  ...
# DTX1                      0                        2           0  ...
# CD70                      0                        0           0  ...
# TNFAIP3                   0                        0           0  ...
# NOTCH2                    0                        2           0  ...
# ...                     ...                      ...         ...  ...
# X1Q32.1.AMP               0                        0           0  ...
# BCL11A                    0                        0           0  ...
# IRF4                      0                        0           0  ...
# LYN                       0                        0           0  ...
# ETS1                      0                        0           0  ...
#
#                  DLBCL11455  DLBCL_RICOVER_685  DLBCL_LS146  \
# classifier_name
# SV.BCL6                   0                  0            0
# DTX1                      1                  0            0
# CD70                      0                  0            0
# TNFAIP3                   0                  0            0
# NOTCH2                    0                  0            2
# ...                     ...                ...          ...
# X1Q32.1.AMP               2                  0            0
# BCL11A                    0                  0            0
# IRF4                      2                  0            0
# LYN                       0                  0            0
# ETS1                      0                  0            0
#
#                  DLBCL_RICOVER_111  DLBCL_RICOVER_173  DLBCL11515  DLBCL10491  \
# classifier_name
# SV.BCL6                          0                  0           0           0
# DTX1                             0                  0           0           0
# CD70                             0                  0           0           0
# TNFAIP3                          0                  0           0           0
# NOTCH2                           0                  0           0           0
# ...                            ...                ...         ...         ...
# X1Q32.1.AMP                      0                  0           0           0
# BCL11A                           1                  0           0           0
# IRF4                             1                  0           0           0
# LYN                              0                  0           0           0
# ETS1                             0                  0           0           0
#
#                  DLBCL_RICOVER_1046  DLBCL10547  DLBCL10998
# classifier_name
# SV.BCL6                           0           0           0
# DTX1                              0           0           0
# CD70                              0           0           0
# TNFAIP3                           0           2           2
# NOTCH2                            0           0           2
# ...                             ...         ...         ...
# X1Q32.1.AMP                       0           0           0
# BCL11A                            0           0           0
# IRF4                              0           0           0
# LYN                               0           0           0
# ETS1                              0           0           0
#
# [163 rows x 699 columns]

# %%
labels = pd.read_csv('../../data_tables/confidence_tables/baseline_probabilities.connectivity_based.sensitivity_power2.Sep_23_2022.tsv',
                    sep='\t', index_col=0)
labels
# Out:
#                          C1        C2        C3        C4        C5  cluster  \
# DLBCL10877         0.985597  0.002210  0.000684  0.010885  0.000625        1
# DLBCL10928         0.984814  0.001006  0.000431  0.013195  0.000553        1
# DLBCL_MC_F648_JKW  0.984740  0.003482  0.000594  0.010454  0.000730        1
# DLBCL10844         0.984523  0.000563  0.000372  0.011383  0.003159        1
# DLBCL11501         0.983851  0.002258  0.000601  0.012017  0.001273        1
# ...                     ...       ...       ...       ...       ...      ...
# DLBCL_C_D_PAIR20   0.000572  0.025097  0.384317  0.002925  0.587090        5
# DLBCL11504         0.159420  0.000438  0.000508  0.264150  0.575484        5
# DLBCL_RICOVER_150  0.000390  0.463520  0.000404  0.002014  0.533672        5
# DLBCL11538         0.003331  0.000994  0.228558  0.235071  0.532045        5
# DLBCL_RICOVER_105  0.054116  0.412816  0.053926  0.054698  0.424443        5
#
#                    confidence
# DLBCL10877           0.985597
# DLBCL10928           0.984814
# DLBCL_MC_F648_JKW    0.984740
# DLBCL10844           0.984523
# DLBCL11501           0.983851
# ...                       ...
# DLBCL_C_D_PAIR20     0.587090
# DLBCL11504           0.575484
# DLBCL_RICOVER_150    0.533672
# DLBCL11538           0.532045
# DLBCL_RICOVER_105    0.424443
#
# [699 rows x 7 columns]

# %%
# Out:
# 16

# %%
tp53_biallelic = ((gsm.loc['TP53'] != 0) & (gsm.loc['X17P.DEL'] != 0)).astype(int)
myc_bcl2 = ((gsm.loc['SV.MYC'] != 0) & (gsm.loc['SV.BCL2'] != 0)).astype(int)

# %%
c2_bi = tp53_biallelic.loc[labels.loc[labels['cluster'] == 2].index].value_counts()
rest_bi = tp53_biallelic.loc[labels.loc[labels['cluster'] != 2].index].value_counts()

m = np.array([[0, 0]] * 2)
m[0, 0] = rest_bi[0]
m[1, 0] = rest_bi[1]
m[0, 1] = c2_bi[0]
m[1, 1] = c2_bi[1]

p_g = fisher_exact_2x2(m, 'two.sided')[0][0]

# %%
p_g, m
# Out:
# (7.987364899543694e-24,
#  array([[500, 106],
#         [ 28,  65]]))

# %%
c2_double = myc_bcl2.loc[labels.loc[labels['cluster'] == 3].index].value_counts()
rest_double = myc_bcl2.loc[labels.loc[labels['cluster'] != 3].index].value_counts()

m = np.array([[0, 0]] * 2)
m[0, 0] = c2_double[0]
m[1, 0] = c2_double[1]
m[0, 1] = rest_double[0]
m[1, 1] = rest_double[1]

p_g = fisher_exact_2x2(m, 'two.sided')[0][0]
p_g, m
# Out:
# (1.610426348613921e-08,
#  array([[104, 579],
#         [ 13,   3]]))

# %%
labels.loc[gsm.columns[((gsm.loc['SV.MYC'] == 3) & (gsm.loc['SV.BCL2'] == 3))], 'cluster'].value_counts()
# Out:
# 3    13
# 4     2
# 2     1
# Name: cluster, dtype: int64

# %%
seg_file = pd.read_csv('../../data_tables/additional_gsm_inputs/DLBCL_786_segs.2021-12-15.ccf.txt', sep='\t', index_col=0)
seg_file = seg_file.loc[seg_file.index.isin(labels.index)]
seg_file.to_csv('../../data_tables/additional_gsm_inputs/DLBCL_699_segs.2021-12-15.ccf.txt', sep='\t')
# Out:
# (76397, 37)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (33) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#               Chromosome      Start        End  n_probes     length  n_hets  \
# Sample
# DFCIDL001_DT           1      69549   16890559      1402   16821010     NaN
# DFCIDL001_DT           1   16892430   16893759         5       1329     NaN
# DFCIDL001_DT           1   16895649  113661999      6004   96766350     NaN
# DFCIDL001_DT           1  116563423  117753461       101    1190038     NaN
# DFCIDL001_DT           1  117944935  228451954      5973  110507019     NaN
# ...                  ...        ...        ...       ...        ...     ...
# DLBCL11685             9      46587   66482225     31211   66435638   453.0
# DLBCL11685             9   66517546   69065736        94    2548190     2.0
# DLBCL11685             9   69088194  135957428     45400   66869234   919.0
# DLBCL11685             9  135962473  135968086         5       5613     3.0
# DLBCL11685             9  135974079  141091382      2404    5117303   409.0
#
#                      f       tau  sigma_tau  mu_minor  ...  muA_nextbest  \
# Sample                                                 ...
# DFCIDL001_DT  0.493503  2.024985   0.050427  0.999336  ...      1.002388
# DFCIDL001_DT       NaN  1.027959   0.074831       NaN  ...           NaN
# DFCIDL001_DT  0.500000  1.999728   0.050098  0.999864  ...      1.002388
# DFCIDL001_DT  0.322857  1.356260   0.052603  0.437878  ...      0.671075
# DFCIDL001_DT  0.500000  2.007921   0.050099  1.003960  ...      1.002388
# ...                ...       ...        ...       ...  ...           ...
# DLBCL11685    0.500000  1.962020   0.050089  0.981010  ...      0.978259
# DLBCL11685    0.151843  1.767794   0.070193  0.268428  ...      0.644892
# DLBCL11685    0.500000  1.963972   0.050072  0.981986  ...      0.978259
# DLBCL11685    0.207849  1.656899   0.196319  0.344385  ...      0.340514
# DLBCL11685    0.500000  1.969411   0.051421  0.984706  ...      0.985506
#
#               muB_nextbest  tau_nextbest    purity   ploidy  gender  IS_SCNA  \
# Sample
# DFCIDL001_DT      1.014436      2.016825  0.600953  1.99207     NaN      0.0
# DFCIDL001_DT           NaN      1.402388  0.600953  1.99207     NaN      1.0
# DFCIDL001_DT      1.002388      2.004777  0.600953  1.99207     NaN      0.0
# DFCIDL001_DT      0.671075      1.342150  0.600953  1.99207     NaN      1.0
# DFCIDL001_DT      1.002388      2.004777  0.600953  1.99207     NaN      0.0
# ...                    ...           ...       ...      ...     ...      ...
# DLBCL11685        0.992753      1.985400  0.730000  2.02000       M      NaN
# DLBCL11685        1.688474      2.350400  0.730000  2.02000       M      NaN
# DLBCL11685        0.992753      1.985400  0.730000  2.02000       M      NaN
# DLBCL11685        0.992753      1.343000  0.730000  2.02000       M      NaN
# DLBCL11685        0.992753      1.992700  0.730000  2.02000       M      NaN
#
#               NCN  Segment_Mean  equal
# Sample
# DFCIDL001_DT  2.0         0.018   True
# DFCIDL001_DT  2.0        -0.960   True
# DFCIDL001_DT  2.0        -0.000   True
# DFCIDL001_DT  2.0        -0.560   True
# DFCIDL001_DT  2.0         0.006   True
# ...           ...           ...    ...
# DLBCL11685    2.0        -0.028   True
# DLBCL11685    2.0        -0.178   True
# DLBCL11685    2.0        -0.026   True
# DLBCL11685    2.0        -0.272   True
# DLBCL11685    2.0        -0.022   True
#
# [71077 rows x 37 columns]

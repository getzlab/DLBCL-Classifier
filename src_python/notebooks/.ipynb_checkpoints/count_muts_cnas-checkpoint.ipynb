# %%
import pandas as pd

# %%
samples = pd.read_csv('../../data_tables/confidence_tables/baseline_probabilities.connectivity_based.sensitivity_power2.Sep_23_2022.tsv',
                     sep='\t', index_col=0).index
samples
# Out:
# Index(['DLBCL10844', 'DLBCL_C_D_1129_NULLPAIR', 'DLBCL10525', 'DLBCL11486',
#        'DLBCL10458', 'DLBCL_MC_F262_WLC', 'DLBCL11509', 'DLBCL11443',
#        'DLBCL10972', 'DLBCL10986',
#        ...
#        'DLBCL10973', 'DLBCL_C_D_1142_NULLPAIR', 'DLBCL11471',
#        'DLBCL_RICOVER_720', 'DLBCL11538', 'DLBCL11447', 'DLBCL11491',
#        'DLBCL10486', 'DLBCL11448', 'DLBCL_RICOVER_105'],
#       dtype='object', length=699)

# %%
sig_genes = pd.read_csv('../../data_tables/qval_dfs/fisher_exact_5x2.Sep_23_2022.combined.tsv', 
                        sep='\t', index_col=0)
sg = sig_genes.loc[sig_genes['q'] < 0.10].index
sg = sg.str.replace('.', '-', regex=False)
sg = [x for x in sg if '-AMP' not in x and '-DEL' not in x and 'SV-' not in x]
sg
# Out:
# ['DTX1',
#  'CD70',
#  'TNFAIP3',
#  'NOTCH2',
#  'BCL10',
#  'CD58',
#  'B2M',
#  'UBE2A',
#  'ZEB2',
#  'GNAI2',
#  'TMEM30A',
#  'EBF1',
#  'FAS',
#  'HIST1H2BC',
#  'BCL7A',
#  'NFKBIE',
#  'SPEN',
#  'FADD',
#  'CXCR4',
#  'BCL6',
#  'IKZF3',
#  'TNIP1',
#  'ARID1A',
#  'MYD88-OTHER',
#  'POU2F2',
#  'TUBGCP5',
#  'LYN',
#  'SMG7',
#  'CXCR5',
#  'CCDC27',
#  'RHOA',
#  'CCND3',
#  'TP53',
#  'ZNF423',
#  'PDE4DIP',
#  'EP300',
#  'BCL2',
#  'CREBBP',
#  'TNFRSF14',
#  'EZH2',
#  'HVCN1',
#  'KMT2D',
#  'GNA13',
#  'SOCS1',
#  'RAC2',
#  'MAP2K1',
#  'MEF2C',
#  'IRF8',
#  'EEF1A1',
#  'MEF2B',
#  'POU2AF1',
#  'IKBKB',
#  'SGK1',
#  'HIST1H1E',
#  'LTB',
#  'ZFP36L1',
#  'CD83',
#  'NFKBIA',
#  'TET2',
#  'ACTB',
#  'PTPN6',
#  'BRAF',
#  'STAT3',
#  'KLHL6',
#  'HIST1H1B',
#  'HIST1H2AM',
#  'SESN3',
#  'HIST1H1C',
#  'CRIP1',
#  'HIST1H2AC',
#  'PTEN',
#  'YY1',
#  'KRAS',
#  'HIST1H1D',
#  'PABPC1',
#  'CD274',
#  'ZNF608',
#  'OR51B6',
#  'OR10V1',
#  'PIM1',
#  'MYD88',
#  'BTG1',
#  'CD79B',
#  'MYD88-L265P',
#  'IGLL5',
#  'TBL1XR1',
#  'ETV6',
#  'BTG2',
#  'TMSB4X',
#  'PRDM1',
#  'DUSP2',
#  'GRHPR',
#  'HLA-B',
#  'CARD11',
#  'HLA-A',
#  'OSBPL10',
#  'TOX',
#  'IRF2BP2',
#  'BCOR',
#  'HLA-C',
#  'SF3B1',
#  'ZC3H12A',
#  'VMP1',
#  'ATP2A2']

# %%
segs = pd.read_csv('/Users/twood/Desktop/DLBCL_Feature_Matrix_Generation/inputs_for_gene_sample_matrix/DLBCL_786_segs.2021-12-15.ccf.txt',
                  sep='\t', index_col=0, low_memory=False)
segs
# Out:
#               Chromosome      Start        End  n_probes     length  n_hets  \
# Sample
# DFCIDL001_DT           1      69549   16890559      1402   16821010     NaN
# DFCIDL001_DT           1   16892430   16893759         5       1329     NaN
# DFCIDL001_DT           1   16895649  113661999      6004   96766350     NaN
# DFCIDL001_DT           1  116563423  117753461       101    1190038     NaN
# DFCIDL001_DT           1  117944935  228451954      5973  110507019     NaN
# ...                  ...        ...        ...       ...        ...     ...
# DLBCL11685             9      46587   66482225     31211   66435638   453.0
# DLBCL11685             9   66517546   69065736        94    2548190     2.0
# DLBCL11685             9   69088194  135957428     45400   66869234   919.0
# DLBCL11685             9  135962473  135968086         5       5613     3.0
# DLBCL11685             9  135974079  141091382      2404    5117303   409.0
#
#                      f       tau  sigma_tau  mu_minor  ...  muA_nextbest  \
# Sample                                                 ...
# DFCIDL001_DT  0.493503  2.024985   0.050427  0.999336  ...      1.002388
# DFCIDL001_DT       NaN  1.027959   0.074831       NaN  ...           NaN
# DFCIDL001_DT  0.500000  1.999728   0.050098  0.999864  ...      1.002388
# DFCIDL001_DT  0.322857  1.356260   0.052603  0.437878  ...      0.671075
# DFCIDL001_DT  0.500000  2.007921   0.050099  1.003960  ...      1.002388
# ...                ...       ...        ...       ...  ...           ...
# DLBCL11685    0.500000  1.962020   0.050089  0.981010  ...      0.978259
# DLBCL11685    0.151843  1.767794   0.070193  0.268428  ...      0.644892
# DLBCL11685    0.500000  1.963972   0.050072  0.981986  ...      0.978259
# DLBCL11685    0.207849  1.656899   0.196319  0.344385  ...      0.340514
# DLBCL11685    0.500000  1.969411   0.051421  0.984706  ...      0.985506
#
#               muB_nextbest  tau_nextbest    purity   ploidy  gender  IS_SCNA  \
# Sample
# DFCIDL001_DT      1.014436      2.016825  0.600953  1.99207     NaN      0.0
# DFCIDL001_DT           NaN      1.402388  0.600953  1.99207     NaN      1.0
# DFCIDL001_DT      1.002388      2.004777  0.600953  1.99207     NaN      0.0
# DFCIDL001_DT      0.671075      1.342150  0.600953  1.99207     NaN      1.0
# DFCIDL001_DT      1.002388      2.004777  0.600953  1.99207     NaN      0.0
# ...                    ...           ...       ...      ...     ...      ...
# DLBCL11685        0.992753      1.985400  0.730000  2.02000       M      NaN
# DLBCL11685        1.688474      2.350400  0.730000  2.02000       M      NaN
# DLBCL11685        0.992753      1.985400  0.730000  2.02000       M      NaN
# DLBCL11685        0.992753      1.343000  0.730000  2.02000       M      NaN
# DLBCL11685        0.992753      1.992700  0.730000  2.02000       M      NaN
#
#               NCN  Segment_Mean  equal
# Sample
# DFCIDL001_DT  2.0         0.018   True
# DFCIDL001_DT  2.0        -0.960   True
# DFCIDL001_DT  2.0        -0.000   True
# DFCIDL001_DT  2.0        -0.560   True
# DFCIDL001_DT  2.0         0.006   True
# ...           ...           ...    ...
# DLBCL11685    2.0        -0.028   True
# DLBCL11685    2.0        -0.178   True
# DLBCL11685    2.0        -0.026   True
# DLBCL11685    2.0        -0.272   True
# DLBCL11685    2.0        -0.022   True
#
# [76397 rows x 37 columns]

# %%
svs = pd.read_csv('/Users/twood/Desktop/DLBCL_Feature_Matrix_Generation/inputs_for_gene_sample_matrix/DLBCL_Shipp_Staudt.SVs.14-Dec-2021.txt',
                 sep='\t', index_col=0)
svs = svs.loc[~svs['class'].isna()]
svs
# Out:
#             individual   num  str1  chr1         pos1  str2  chr2  \
# 22        DFCIDL001_DT   8.0   1.0   9.0    5078217.0   0.0   9.0
# 23        DFCIDL001_DT  10.0   0.0   9.0    5568155.0   0.0   9.0
# 24        DFCIDL001_DT  19.0   1.0  12.0  122460270.0   0.0  14.0
# 25        DFCIDL001_DT  28.0   1.0   9.0    5078220.0   1.0   9.0
# 26        DFCIDL001_DT  32.0   0.0  16.0   10972248.0   1.0  16.0
# ..                 ...   ...   ...   ...          ...   ...   ...
# 437  DLBCL_RICOVER_948  38.0   0.0  14.0  106329473.0   1.0  18.0
# 438  DLBCL_RICOVER_956  23.0   1.0   6.0   90812770.0   0.0  14.0
# 439  DLBCL_RICOVER_956  38.0   0.0   6.0   90812806.0   1.0  14.0
# 440  DLBCL_RICOVER_977  28.0   1.0   3.0  187462683.0   0.0  15.0
# 441   DLBCL_RICOVER_99  11.0   1.0   2.0  145364159.0   0.0  14.0
#
#             pos2       class      span  ...  CCF1CI_high  CCF1_MODEL  \
# 22     5388547.0  tandem_dup  310330.0  ...          NaN         NaN
# 23     5584951.0   inversion   16790.0  ...          NaN         NaN
# 24   106326737.0   inter_chr       NaN  ...          NaN         NaN
# 25     5883844.0   inversion  805563.0  ...          NaN         NaN
# 26    11349188.0    deletion  376934.0  ...          NaN         NaN
# ..           ...         ...       ...  ...          ...         ...
# 437   60793552.0   inter_chr       NaN  ...          NaN         NaN
# 438  106326839.0   inter_chr       NaN  ...          NaN         NaN
# 439  106326794.0   inter_chr       NaN  ...          NaN         NaN
# 440   72520186.0   inter_chr       NaN  ...          NaN         NaN
# 441  106112633.0   inter_chr       NaN  ...          NaN         NaN
#
#      CCF1_multiplicity  CCF1_negativeLogLikelihood  CCF2  CCF2CI_low  \
# 22                 NaN                         NaN   NaN         NaN
# 23                 NaN                         NaN   NaN         NaN
# 24                 NaN                         NaN   NaN         NaN
# 25                 NaN                         NaN   NaN         NaN
# 26                 NaN                         NaN   NaN         NaN
# ..                 ...                         ...   ...         ...
# 437                NaN                         NaN   NaN         NaN
# 438                NaN                         NaN   NaN         NaN
# 439                NaN                         NaN   NaN         NaN
# 440                NaN                         NaN   NaN         NaN
# 441                NaN                         NaN   NaN         NaN
#
#      CCF2CI_high  CCF2_MODEL  CCF2_multiplicity  CCF2_negativeLogLikelihood
# 22           NaN         NaN                NaN                         NaN
# 23           NaN         NaN                NaN                         NaN
# 24           NaN         NaN                NaN                         NaN
# 25           NaN         NaN                NaN                         NaN
# 26           NaN         NaN                NaN                         NaN
# ..           ...         ...                ...                         ...
# 437          NaN         NaN                NaN                         NaN
# 438          NaN         NaN                NaN                         NaN
# 439          NaN         NaN                NaN                         NaN
# 440          NaN         NaN                NaN                         NaN
# 441          NaN         NaN                NaN                         NaN
#
# [420 rows x 185 columns]

# %%
maf = pd.read_csv('../../data_tables/maf_files/DLBCL_combined_699.hg38B.noPDE4DIP.noHISTartifacts.maf', sep='\t')
maf.head()
# Out:
#   Hugo_Symbol Chromosome  Start_position  End_position Tumor_Sample_Barcode  \
# 0     CBFA2T2         20        32232306      32232306         DFCIDL003_DT
# 1       MICU2         13        22069394      22069394         DFCIDL003_DT
# 2     UGT2B11          4        70079916      70079916         DFCIDL003_DT
# 3        ODC1          2        10583919      10583919         DFCIDL003_DT
# 4      LIN28B          6       105406020     105406020         DFCIDL003_DT
#
#   Variant_Classification Reference_Allele Tumor_Seq_Allele1 Tumor_Seq_Allele2  \
# 0      Missense_Mutation                C                 C                 T
# 1      Missense_Mutation                G                 G                 C
# 2                 Silent                A                 A                 T
# 3      Missense_Mutation                G                 G                 A
# 4                 Silent                G                 G                 A
#
#    t_alt_count  t_ref_count Protein_Change
# 0         40.0         44.0        p.R557W
# 1         12.0         23.0        p.T369S
# 2         36.0         87.0        p.T175T
# 3         56.0         58.0        p.R165C
# 4          7.0         65.0         p.E19E

# %%
muts_per_sample = maf['Tumor_Sample_Barcode'].value_counts().sort_values()

# %%
def calc_cna_perc(sample):
    tmpdf = segs.loc[sample]
    total_cov = sum(tmpdf['End'] - tmpdf['Start'] + 1)

    del_cov = tmpdf.loc[tmpdf['Segment_Mean'] < -0.1]
    del_cov = sum(del_cov['End'] - del_cov['Start'] + 1)

    amp_cov = tmpdf.loc[tmpdf['Segment_Mean'] > 0.1]
    amp_cov = sum(amp_cov['End'] - amp_cov['Start'] + 1)
    
    del_frac = del_cov / total_cov
    amp_frac = amp_cov / total_cov
    
    return del_frac, amp_frac

# %%
calc_cna_perc('DFCIDL001_DT')
# Out:
# (0.046661315220490406, 0.048961992193796496)

# %%
cna_fracs = {}
for s in set(segs.index):
    d_f, a_f = calc_cna_perc(s)
    cna_fracs[s] = [d_f, a_f]

# %%
muts_per_sample = muts_per_sample.loc[samples]
muts_per_sample
# Out:
# DLBCL10844                 106
# DLBCL_C_D_1129_NULLPAIR    109
# DLBCL10525                 269
# DLBCL11486                 760
# DLBCL10458                 450
#                           ...
# DLBCL11447                 381
# DLBCL11491                 380
# DLBCL10486                 123
# DLBCL11448                 151
# DLBCL_RICOVER_105           33
# Name: Tumor_Sample_Barcode, Length: 699, dtype: int64

# %%
cna_df = pd.DataFrame.from_dict(cna_fracs, orient='index')
cna_df = cna_df.loc[samples]
cna_df.columns = ['del_frac', 'amp_frac']
cna_df['muts'] = muts_per_sample
cna_df
# Out:
#                          del_frac  amp_frac  muts
# DLBCL10844               0.016773  0.145399   106
# DLBCL_C_D_1129_NULLPAIR  0.002362  0.075987   109
# DLBCL10525               0.006391  0.068952   269
# DLBCL11486               0.025336  0.085450   760
# DLBCL10458               0.065634  0.132372   450
# ...                           ...       ...   ...
# DLBCL11447               0.013228  0.118721   381
# DLBCL11491               0.044660  0.148088   380
# DLBCL10486               0.012738  0.173262   123
# DLBCL11448               0.001423  0.109829   151
# DLBCL_RICOVER_105        0.042758  0.132234    33
#
# [699 rows x 3 columns]

# %%
shipp_samples = pd.read_csv('../../data_tables/sample_sets/ShippStaudtSets.purity0.2.txt', sep='\t', index_col=0)
shipp_samples = shipp_samples.loc[shipp_samples['cohort'] == 'Shipp'].index
shipp_samples
# Out:
# Index(['DFCIDL001_DT', 'DFCIDL010_DT', 'DLBCL_RICOVER_290',
#        'DLBCL_RICOVER_451', 'DLBCL_RICOVER_473', 'DLBCL_RICOVER_694',
#        'DLBCL_RICOVER_826', 'DLBCL_RICOVER_829', 'DLBCL_RICOVER_865',
#        'DLBCL_RICOVER_945',
#        ...
#        'DLBCL_RICOVER_1192', 'DLBCL_RICOVER_1106', 'DLBCL_RICOVER_1190',
#        'DLBCL_MC_F990_MNA', 'DLBCL_C_D_PAIR2', 'DLBCL_C_D_PAIR20',
#        'DLBCL_C_D_PAIR22', 'DLBCL_C_D_PAIR23', 'DLBCL_C_D_PAIR5',
#        'DLBCL_C_D_PAIR9'],
#       dtype='object', name='SampleName', length=277)

# %%
sv_counts = svs.loc[svs['individual'].isin(shipp_samples)]

# %%
sv_counts = sv_counts['individual'].value_counts()
sv_counts = pd.DataFrame(sv_counts, index=sv_counts.index)
sv_counts
# Out:
#                          individual
# DLBCL_C_D_1148_NULLPAIR          18
# DLBCL_C_D_1157_NULLPAIR          12
# DLBCL_C_D_1106_NULLPAIR           7
# DLBCL_C_D_1129_NULLPAIR           7
# DLBCL_RICOVER_678                 7
# ...                             ...
# DLBCL_RICOVER_1269                1
# DLBCL_RICOVER_1263                1
# DLBCL_C_D_1127_NULLPAIR           1
# DLBCL_RICOVER_1248                1
# DLBCL_RICOVER_99                  1
#
# [173 rows x 1 columns]

# %%
no_svs = shipp_samples[~shipp_samples.isin(sv_counts.index)]

# %%
for s in no_svs:
    sv_counts.loc[s] = 0

# %%
sv_counts
# Out:
#                          individual
# DLBCL_C_D_1148_NULLPAIR          18
# DLBCL_C_D_1157_NULLPAIR          12
# DLBCL_C_D_1106_NULLPAIR           7
# DLBCL_C_D_1129_NULLPAIR           7
# DLBCL_RICOVER_678                 7
# ...                             ...
# DLBCL_C_D_PAIR20                  0
# DLBCL_C_D_PAIR22                  0
# DLBCL_C_D_PAIR23                  0
# DLBCL_C_D_PAIR5                   0
# DLBCL_C_D_PAIR9                   0
#
# [277 rows x 1 columns]

# %%
sv_counts.to_csv('../../data_tables/raw_sv_counts.tsv', sep='\t')

# %%
cna_df.to_csv('../../data_tables/raw_muts_cnas_counts.tsv', sep='\t')

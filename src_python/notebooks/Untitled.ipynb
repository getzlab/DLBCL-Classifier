# %%
import pandas as pd

# %%
mutsig_table = pd.read_csv('../../data_tables/mutsig2cv_gistic_qvalues/DLBCL_550_training_noPDE4DIP_noHISTartifacts.sig_genes.txt', sep='\t')

# %%
mutsig_table[mutsig_table['q'] < 0.1]
# Out:
#        gene                                           longname  codelen  nnei  \
# 0      PIM1                                     pim-1 oncogene      962     0
# 1     MYD88  myeloid differentiation primary response gene ...      971     1
# 2      TP53                                  tumor protein p53     1422     1
# 3    CREBBP   CREB binding protein (Rubinstein-Taybi syndrome)     7449     3
# 4     CD79B     CD79b molecule, immunoglobulin-associated beta      713     0
# ..      ...                                                ...      ...   ...
# 181   OLIG1             oligodendrocyte transcription factor 1      816     3
# 182   FCRL3                                 Fc receptor-like 3     2285     3
# 183    TSR1  TSR1, 20S rRNA accumulation, homolog (S. cerev...     2483     6
# 184   ADCY7                                adenylate cyclase 7     3386     0
# 185   POTEH               POTE ankyrin domain family, member H     1676   153
#
# ...

# %%
mutsig_table_all = pd.read_csv('../../data_tables/mutsig2cv_gistic_qvalues/DLBCL_699_noPDE4DIP_noHISTartfacts.sig_genes.txt', sep='\t')

# %%
mutsig_table_all[mutsig_table_all['q'] < 0.1]
# Out:
#      rank     gene                                           longname  \
# 0       1    MYD88  myeloid differentiation primary response gene ...
# 1       2     TP53                                  tumor protein p53
# 2       3   CREBBP   CREB binding protein (Rubinstein-Taybi syndrome)
# 3       4    HLA-B       major histocompatibility complex, class I, B
# 4       5  TBL1XR1       transducin (beta)-like 1 X-linked receptor 1
# ..    ...      ...                                                ...
# 295   296    KIF24                           kinesin family member 24
# 296   297    NTRK1     neurotrophic tyrosine kinase, receptor, type 1
# 297   298    PTPRC     protein tyrosine phosphatase, receptor type, C
# 298   299    SFXN3                                     sideroflexin 3
# 299   300    TDRD6                          tudor domain containing 6
#
#      codelen  nnei  nncd  nsil  nmis  nstp  nspl  nind  nnon  npat  nsite  \
# ...
